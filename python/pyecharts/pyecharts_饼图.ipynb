# %%
from example.commons import Faker
from pyecharts import options as opts
from pyecharts.charts import Page, Pie

# %%
def pie_base() -> Pie:
    c = (
        Pie()
        .add("", [list(z) for z in zip(Faker.choose(), Faker.values())])
        .set_global_opts(title_opts=opts.TitleOpts(title="Pie-基本示例"))
        .set_series_opts(label_opts=opts.LabelOpts(formatter="{a}-{b}-{c}-{d}"))# abcd具有不同数据含义
    )# b:名称  c:数值  d:占比
    return c

# %%
pie_base().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="c8b3b41e22ae402f919d8f42ca36da86" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_c8b3b41e22ae402f919d8f42ca36da86 = echarts.init(
#             document.getElementById('c8b3b41e22ae402f919d8f42ca36da86'), 'white', {renderer: 'canvas'});
#         var option_c8b3b41e22ae402f919d8f42ca36da86 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 113
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 71
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 83
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 79
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 141
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 32
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{a}-{b}-{c}-{d}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#         chart_c8b3b41e22ae402f919d8f42ca36da86.setOption(option_c8b3b41e22ae402f919d8f42ca36da86);
#     });
# </script>

# %%
[list(z) for z in zip(Faker.choose(), Faker.values())]
# Out:
# [['哈士奇', 58],
#  ['萨摩耶', 25],
#  ['泰迪', 148],
#  ['金毛', 150],
#  ['牧羊犬', 117],
#  ['吉娃娃', 120],
#  ['柯基', 30]]

# %%
# 中心为空
def pie_radius() -> Pie:
    c = (
        Pie()
        .add(
            "",
            [list(z) for z in zip(Faker.choose(), Faker.values())],
            radius=["30%", "70%"],# [内半径,外半径]
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Pie-Radius"),
            legend_opts=opts.LegendOpts(
                orient="vertical", pos_top="15%", pos_left="2%"
            ),
        )
        .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    )
    return c

# %%
pie_radius().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="d17410b84b5d4b97afa4cb898f313ae4" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_d17410b84b5d4b97afa4cb898f313ae4 = echarts.init(
#             document.getElementById('d17410b84b5d4b97afa4cb898f313ae4'), 'white', {renderer: 'canvas'});
#         var option_d17410b84b5d4b97afa4cb898f313ae4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u6cb3\u9a6c",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u87d2\u86c7",
#                     "value": 47
#                 },
#                 {
#                     "name": "\u8001\u864e",
#                     "value": 149
#                 },
#                 {
#                     "name": "\u5927\u8c61",
#                     "value": 93
#                 },
#                 {
#                     "name": "\u5154\u5b50",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u72ee\u5b50",
#                     "value": 53
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "70%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "15%",
#             "orient": "vertical"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-Radius"
#         }
#     ]
# };
#         chart_d17410b84b5d4b97afa4cb898f313ae4.setOption(option_d17410b84b5d4b97afa4cb898f313ae4);
#     });
# </script>

# %%
def pie_rosetype() -> Pie:
    v = Faker.choose()
    c = (
        Pie()
        .add(
            "",
            [list(z) for z in zip(v, Faker.values())],
            radius=["30%", "75%"],
            center=["25%", "50%"],# 圆中心位置
            rosetype="radius",
            label_opts=opts.LabelOpts(is_show=False),
        )
        .add(
            "",
            [list(z) for z in zip(v, Faker.values())],
            radius=["30%", "75%"],
            center=["75%", "50%"],
            rosetype="area",
            # 是否展示成南丁格尔图，通过半径区分数据大小，有'radius'和'area'两种模式。
            # radius：扇区圆心角展现数据的百分比，半径展现数据的大小
            # area：所有扇区圆心角相同，仅通过半径展现数据大小
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="Pie-玫瑰图示例"))
    )
    return c

# %%
pie_rosetype().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="addca88af4db4af9b17bc4c084115ee6" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_addca88af4db4af9b17bc4c084115ee6 = echarts.init(
#             document.getElementById('addca88af4db4af9b17bc4c084115ee6'), 'white', {renderer: 'canvas'});
#         var option_addca88af4db4af9b17bc4c084115ee6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 147
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 134
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 128
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 113
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 105
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 147
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 61
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 93
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 102
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 71
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 49
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 138
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u73ab\u7470\u56fe\u793a\u4f8b"
#         }
#     ]
# };
#         chart_addca88af4db4af9b17bc4c084115ee6.setOption(option_addca88af4db4af9b17bc4c084115ee6);
#     });
# </script>
